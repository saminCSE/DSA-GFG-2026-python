# %%
# NO_ANALYZE
import cr; import importlib; importlib.reload(cr)
# Out:
# ✅  Complexity Runner is now active!
#     ├─ Every cell will show Time & Space complexity after it runs.
#     └─ Add  # NO_ANALYZE  as the first line of any cell to skip it.

# %% [markdown]
# [Naive Approach] Using Loop - O(n) Time and O(1) Space

# %%
def findSum(n):
    sum = 0
    for i in range(1, n + 1):
        sum += i
    return sum

if __name__ == "__main__":
     n = int(input("Enter a number: "))
     print("The sum of first", n, "natural numbers is:", findSum(n))
# Out:
# The sum of first 5 natural numbers is: 15
# <style>
#   .cr-wrap {
#     display: flex; gap: 0;
#     font-family: 'Segoe UI', Arial, sans-serif; font-size: 13px;
#     border: 1px solid #313244; border-radius: 10px;
#     overflow: hidden; margin: 8px 0;
#     box-shadow: 0 4px 12px rgba(0,0,0,.5);
#   }
#   /* ── Left panel (code) ── */
#   .cr-left {
#     flex: 1.5; border-right: 1px solid #313244;
#     padding: 12px 14px; background: #11111b;
#   }
#   /* ── Right panel (analysis) ── */
#   .cr-right {
#     flex: 1; padding: 12px 14px;
#     background: #1e1e2e; color: #cdd6f4;
#     min-width: 240px;
#   }
#   /* ── Shared section label ── */
#   .cr-section {
#     font-size: 10px; font-weight: 700;
#     letter-spacing: .08em; color: #585b70;
#     margin: 6px 0 4px; text-transform: uppercase;
#   }
#   /* ── Code block ── */
#   .cr-code {
#     background: #181825; border-radius: 6px;
#     padding: 10px 12px;
#     font-family: 'Fira Code','Cascadia Code','Courier New',monospace;
#     font-size: 12.5px; white-space: pre; overflow-x: auto;
#     color: #cdd6f4; line-height: 1.65; margin: 0;
#     border: 1px solid #313244;
#   }
#   /* ── Badge row ── */
#   .cr-badges { display: flex; gap: 8px; margin: 6px 0 10px; }
#   .cr-badge {
#     flex: 1; border: 2px solid; border-radius: 8px;
#     padding: 8px 6px; text-align: center;
#   }
#   .cr-badge-label {
#     font-size: 10px; font-weight: 700;
#     letter-spacing: .06em; margin-bottom: 3px;
#   }
#   .cr-badge-val {
#     font-size: 17px; font-weight: 800;
#     font-family: 'Fira Code', monospace;
#   }
#   /* ── Breakdown notes ── */
#   .cr-note { font-size: 12px; color: #a6adc8; padding: 2px 0 2px 2px; }
#   .cr-note-t::before { content: "⏱ "; }
#   .cr-note-s::before { content: "💾 "; }
#   .cr-dim { color: #45475a; }
#   /* ── Performance table ── */
#   .cr-perf { border-collapse: collapse; width: 100%; margin-top: 4px; }
#   .cr-plabel { color: #585b70; font-size: 12px; padding: 3px 8px 3px 0; width: 105px; }
#   .cr-pval   { font-weight: 700; font-size: 13px; color: #cdd6f4; }
#   .cr-warn   { font-size: 11px; color: #f38ba8; padding-left: 6px; }
#   .cr-error  { color: #f38ba8; }
#   /* ── Divider ── */
#   .cr-hr { border: none; border-top: 1px solid #313244; margin: 8px 0; }
# </style>
#
# <div class="cr-wrap">
#   <div class="cr-left">
#     <div class="cr-section">Code</div>
#     <pre class="cr-code">def findSum(n):
#     sum = 0
#     for i in range(1, n + 1):
#         sum += i
#     return sum
#
# if __name__ == &quot;__main__&quot;:
#      n = int(input(&quot;Enter a number: &quot;))
#      print(&quot;The sum of first&quot;, n, &quot;natural numbers is:&quot;, findSum(n))</pre>
#   </div>
#   <div class="cr-right">
#
#         <div class="cr-section">Complexity</div>
#         <div class="cr-badges">
#           <div class="cr-badge"
#                style="color:#3b82f6;background:#0c1a3d;border-color:#3b82f6">
#             <div class="cr-badge-label">⏱ TIME</div>
#             <div class="cr-badge-val">O(n)</div>
#           </div>
#           <div class="cr-badge"
#                style="color:#22c55e;background:#052e16;border-color:#22c55e">
#             <div class="cr-badge-label">💾 SPACE</div>
#             <div class="cr-badge-val">O(1)</div>
#           </div>
#         </div>
#
#         <div class="cr-section">Breakdown</div>
#         <div class="cr-note cr-note-t">Single loop  →  linear time</div><div class="cr-note cr-note-s">Only scalar / fixed-size variables  →  constant space</div>
#
#         <hr class="cr-hr"/>
#         <div class="cr-section">Actual Performance</div>
#         <table class="cr-perf">
#           <tr>
#             <td class="cr-plabel">Runtime</td>
#             <td class="cr-pval">2099.377 ms</td>
#             <td class="cr-warn">⚠ includes input() wait</td>
#           </tr>
#           <tr>
#             <td class="cr-plabel">Peak Memory</td>
#             <td class="cr-pval">54.58 KB</td>
#             <td></td>
#           </tr>
#         </table>
#
#   </div>
# </div>

# %% [markdown]
# [Alternative Approach] Using Recursion - O(n) Time and O(n) Space
#
# In this approach, we use recursion to find the sum of the first n natural numbers. The function calls itself with (n-1) until it reaches the base case of n = 1. Each call adds the current value of n to the sum of smaller values, effectively building the result in a top-down manner.

# %%
def findSum(n):
    if n == 1:
        return 1
    else:
        return n + findSum(n - 1)
    
if __name__ == "__main__":
     n = int(input("Enter a number: "))
     print("The sum of first", n, "natural numbers is:", findSum(n))
# Out:
# The sum of first 5 natural numbers is: 15
# <style>
#   .cr-wrap {
#     display: flex; gap: 0;
#     font-family: 'Segoe UI', Arial, sans-serif; font-size: 13px;
#     border: 1px solid #313244; border-radius: 10px;
#     overflow: hidden; margin: 8px 0;
#     box-shadow: 0 4px 12px rgba(0,0,0,.5);
#   }
#   /* ── Left panel (code) ── */
#   .cr-left {
#     flex: 1.5; border-right: 1px solid #313244;
#     padding: 12px 14px; background: #11111b;
#   }
#   /* ── Right panel (analysis) ── */
#   .cr-right {
#     flex: 1; padding: 12px 14px;
#     background: #1e1e2e; color: #cdd6f4;
#     min-width: 240px;
#   }
#   /* ── Shared section label ── */
#   .cr-section {
#     font-size: 10px; font-weight: 700;
#     letter-spacing: .08em; color: #585b70;
#     margin: 6px 0 4px; text-transform: uppercase;
#   }
#   /* ── Code block ── */
#   .cr-code {
#     background: #181825; border-radius: 6px;
#     padding: 10px 12px;
#     font-family: 'Fira Code','Cascadia Code','Courier New',monospace;
#     font-size: 12.5px; white-space: pre; overflow-x: auto;
#     color: #cdd6f4; line-height: 1.65; margin: 0;
#     border: 1px solid #313244;
#   }
#   /* ── Badge row ── */
#   .cr-badges { display: flex; gap: 8px; margin: 6px 0 10px; }
#   .cr-badge {
#     flex: 1; border: 2px solid; border-radius: 8px;
#     padding: 8px 6px; text-align: center;
#   }
#   .cr-badge-label {
#     font-size: 10px; font-weight: 700;
#     letter-spacing: .06em; margin-bottom: 3px;
#   }
#   .cr-badge-val {
#     font-size: 17px; font-weight: 800;
#     font-family: 'Fira Code', monospace;
#   }
#   /* ── Breakdown notes ── */
#   .cr-note { font-size: 12px; color: #a6adc8; padding: 2px 0 2px 2px; }
#   .cr-note-t::before { content: "⏱ "; }
#   .cr-note-s::before { content: "💾 "; }
#   .cr-dim { color: #45475a; }
#   /* ── Performance table ── */
#   .cr-perf { border-collapse: collapse; width: 100%; margin-top: 4px; }
#   .cr-plabel { color: #585b70; font-size: 12px; padding: 3px 8px 3px 0; width: 105px; }
#   .cr-pval   { font-weight: 700; font-size: 13px; color: #cdd6f4; }
#   .cr-warn   { font-size: 11px; color: #f38ba8; padding-left: 6px; }
#   .cr-error  { color: #f38ba8; }
#   /* ── Divider ── */
#   .cr-hr { border: none; border-top: 1px solid #313244; margin: 8px 0; }
# </style>
#
# <div class="cr-wrap">
#   <div class="cr-left">
#     <div class="cr-section">Code</div>
#     <pre class="cr-code">def findSum(n):
#     if n == 1:
#         return 1
#     else:
#         return n + findSum(n - 1)
#
# if __name__ == &quot;__main__&quot;:
#      n = int(input(&quot;Enter a number: &quot;))
#      print(&quot;The sum of first&quot;, n, &quot;natural numbers is:&quot;, findSum(n))</pre>
#   </div>
#   <div class="cr-right">
#
#         <div class="cr-section">Complexity</div>
#         <div class="cr-badges">
#           <div class="cr-badge"
#                style="color:#3b82f6;background:#0c1a3d;border-color:#3b82f6">
#             <div class="cr-badge-label">⏱ TIME</div>
#             <div class="cr-badge-val">O(n)</div>
#           </div>
#           <div class="cr-badge"
#                style="color:#3b82f6;background:#0c1a3d;border-color:#3b82f6">
#             <div class="cr-badge-label">💾 SPACE</div>
#             <div class="cr-badge-val">O(n)</div>
#           </div>
#         </div>
#
#         <div class="cr-section">Breakdown</div>
#         <div class="cr-note cr-note-t">Linear recursion (single path, no branching)</div><div class="cr-note cr-note-t">Recursive function call(s) present</div><div class="cr-note cr-note-s">Recursive call stack  →  O(n) depth</div>
#
#         <hr class="cr-hr"/>
#         <div class="cr-section">Actual Performance</div>
#         <table class="cr-perf">
#           <tr>
#             <td class="cr-plabel">Runtime</td>
#             <td class="cr-pval">1990.953 ms</td>
#             <td class="cr-warn">⚠ includes input() wait</td>
#           </tr>
#           <tr>
#             <td class="cr-plabel">Peak Memory</td>
#             <td class="cr-pval">54.45 KB</td>
#             <td></td>
#           </tr>
#         </table>
#
#   </div>
# </div>

# %% [markdown]
# [Expected Approach] Formula Based Method - O(1) Time and O(1) Space
#
# Sum of first n natural numbers = (n * (n+1)) / 2
#
# For example: n = 5
# Sum = (5 * (5 + 1)) / 2 = (5 * 6) / 2 = 30 / 2 = 15
#
# How does this work?
#
# We can prove this formula using induction.
# It is true for n = 1 and n = 2
# For n = 1, sum = 1 * (1 + 1)/2 = 1
# For n = 4, sum = 4* (4 + 1)/2 = 10
# Let it be true for k = n-1.
# Sum of k numbers = (k * (k+1))/2
# Putting k = n-1, we get
# Sum of k numbers = ((n-1) * (n-1+1))/2
#                  = (n - 1) * n / 2
# If we add n, we get,
# Sum of n numbers = n + (n - 1) * n / 2
#                  = (2n + n2 - n)/2
#                  = n * (n + 1)/2

# %%
def findSum(n):
    return (n * (n + 1)) // 2

if __name__ == "__main__":
     n = int(input("Enter a number: "))
     print("The sum of first", n, "natural numbers is:", findSum(n))
# Out:
# The sum of first 5 natural numbers is: 15
# <style>
#   .cr-wrap {
#     display: flex; gap: 0;
#     font-family: 'Segoe UI', Arial, sans-serif; font-size: 13px;
#     border: 1px solid #313244; border-radius: 10px;
#     overflow: hidden; margin: 8px 0;
#     box-shadow: 0 4px 12px rgba(0,0,0,.5);
#   }
#   /* ── Left panel (code) ── */
#   .cr-left {
#     flex: 1.5; border-right: 1px solid #313244;
#     padding: 12px 14px; background: #11111b;
#   }
#   /* ── Right panel (analysis) ── */
#   .cr-right {
#     flex: 1; padding: 12px 14px;
#     background: #1e1e2e; color: #cdd6f4;
#     min-width: 240px;
#   }
#   /* ── Shared section label ── */
#   .cr-section {
#     font-size: 10px; font-weight: 700;
#     letter-spacing: .08em; color: #585b70;
#     margin: 6px 0 4px; text-transform: uppercase;
#   }
#   /* ── Code block ── */
#   .cr-code {
#     background: #181825; border-radius: 6px;
#     padding: 10px 12px;
#     font-family: 'Fira Code','Cascadia Code','Courier New',monospace;
#     font-size: 12.5px; white-space: pre; overflow-x: auto;
#     color: #cdd6f4; line-height: 1.65; margin: 0;
#     border: 1px solid #313244;
#   }
#   /* ── Badge row ── */
#   .cr-badges { display: flex; gap: 8px; margin: 6px 0 10px; }
#   .cr-badge {
#     flex: 1; border: 2px solid; border-radius: 8px;
#     padding: 8px 6px; text-align: center;
#   }
#   .cr-badge-label {
#     font-size: 10px; font-weight: 700;
#     letter-spacing: .06em; margin-bottom: 3px;
#   }
#   .cr-badge-val {
#     font-size: 17px; font-weight: 800;
#     font-family: 'Fira Code', monospace;
#   }
#   /* ── Breakdown notes ── */
#   .cr-note { font-size: 12px; color: #a6adc8; padding: 2px 0 2px 2px; }
#   .cr-note-t::before { content: "⏱ "; }
#   .cr-note-s::before { content: "💾 "; }
#   .cr-dim { color: #45475a; }
#   /* ── Performance table ── */
#   .cr-perf { border-collapse: collapse; width: 100%; margin-top: 4px; }
#   .cr-plabel { color: #585b70; font-size: 12px; padding: 3px 8px 3px 0; width: 105px; }
#   .cr-pval   { font-weight: 700; font-size: 13px; color: #cdd6f4; }
#   .cr-warn   { font-size: 11px; color: #f38ba8; padding-left: 6px; }
#   .cr-error  { color: #f38ba8; }
#   /* ── Divider ── */
#   .cr-hr { border: none; border-top: 1px solid #313244; margin: 8px 0; }
# </style>
#
# <div class="cr-wrap">
#   <div class="cr-left">
#     <div class="cr-section">Code</div>
#     <pre class="cr-code">def findSum(n):
#     return (n * (n + 1)) // 2
#
# if __name__ == &quot;__main__&quot;:
#      n = int(input(&quot;Enter a number: &quot;))
#      print(&quot;The sum of first&quot;, n, &quot;natural numbers is:&quot;, findSum(n))</pre>
#   </div>
#   <div class="cr-right">
#
#         <div class="cr-section">Complexity</div>
#         <div class="cr-badges">
#           <div class="cr-badge"
#                style="color:#22c55e;background:#052e16;border-color:#22c55e">
#             <div class="cr-badge-label">⏱ TIME</div>
#             <div class="cr-badge-val">O(1)</div>
#           </div>
#           <div class="cr-badge"
#                style="color:#22c55e;background:#052e16;border-color:#22c55e">
#             <div class="cr-badge-label">💾 SPACE</div>
#             <div class="cr-badge-val">O(1)</div>
#           </div>
#         </div>
#
#         <div class="cr-section">Breakdown</div>
#         <div class="cr-note cr-note-t">No loops or recursion  →  constant time</div><div class="cr-note cr-note-s">Only scalar / fixed-size variables  →  constant space</div>
#
#         <hr class="cr-hr"/>
#         <div class="cr-section">Actual Performance</div>
#         <table class="cr-perf">
#           <tr>
#             <td class="cr-plabel">Runtime</td>
#             <td class="cr-pval">1871.803 ms</td>
#             <td class="cr-warn">⚠ includes input() wait</td>
#           </tr>
#           <tr>
#             <td class="cr-plabel">Peak Memory</td>
#             <td class="cr-pval">41.84 KB</td>
#             <td></td>
#           </tr>
#         </table>
#
#   </div>
# </div>
